# %%
dataset = [
    {
        'file_name':'customers'
    },
    {
        'file_name':'orders'
    },
    {
        'file_name':'products'
    }
]

# %%
dbutils.jobs.taskValues.set('dataset',dataset)
