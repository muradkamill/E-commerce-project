# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df=spark.read.format('parquet')\
    .load('abfss://bronze@datalakecommerce.dfs.core.windows.net/products')

# %% [markdown]
# ### **Deleting _rescued_data column**

# %%
df=df.drop('_rescued_data')

# %% [markdown]
# ### **adding discounted_price column**

# %%
df=df.withColumn('discounted_price',col("price")*0.9)

# %% [markdown]
# ### **Data Writing**

# %%
df.write.mode('append')\
    .format('delta')\
    .save('abfss://silver@datalakecommerce.dfs.core.windows.net/products')

# %%
# %sql
create table if not exists ecommerce.silver.products
using delta
location 'abfss://silver@datalakecommerce.dfs.core.windows.net/products'
